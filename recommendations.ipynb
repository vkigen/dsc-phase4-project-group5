# %%
import pandas as pd

# %%
def filter_jobs_for_applicant(data_df, recommendations_df, applicant_id):
    recommended_jobs = recommendations_df.loc[recommendations_df['Applicant ID'] == applicant_id, 'Recommended Job IDs']
    if not recommended_jobs.empty:
        job_ids = recommended_jobs.iloc[0]
        return data_df[data_df['Job Id'].isin(job_ids)]
    else:
        return pd.DataFrame()  # Return an empty DataFrame if no recommendations found

# %%
data = pd.read_csv('./data/dataset_first_50k.csv')

# %%
workexres = pd.read_json('./responses/workEx/recommendations.json')

# %%
workexjobs = filter_jobs_for_applicant(data, workexres, 1)

# %%
skillsres = pd.read_json('./responses/skills/recommendations.json')
skillsres
# Out:
#    Applicant ID                                Recommended Job IDs
# 0             1  [1281959944309361, 1730939952508697, 181248059...

# %%
skillsjobs = filter_jobs_for_applicant(data, skillsres, 1)
skillsjobs
# Out:
#                  Job Id     Experience Qualifications Salary Range  \
# 3938    476528205574523   1 to 9 Years         M.Tech   $56K-$100K
# 6498   1943950680816773   0 to 8 Years          M.Com    $62K-$82K
# 14654  1730939952508697  5 to 13 Years            BBA   $60K-$103K
# 19652  1402739641334416  4 to 11 Years            MBA   $61K-$127K
# 22118  1849584946264749  5 to 15 Years            BBA    $57K-$97K
# 29064  2185223408638467  1 to 10 Years         B.Tech   $60K-$101K
# 32089  2034345821344272  2 to 15 Years            PhD    $63K-$81K
# 34999  2762775491366326  5 to 10 Years            BBA   $55K-$126K
# 42916  1812480599522944   3 to 8 Years             BA   $57K-$113K
# 46461  1281959944309361   4 to 8 Years            PhD   $61K-$128K
#
#                         location                   Country  latitude  \
# 3938                      Tarawa                  Kiribati   -3.3704
# 6498                  Paramaribo                  Suriname    3.9193
# 14654                   Belmopan                    Belize   17.1899
# 19652           Andorra la Vella                   Andorra   42.5063
# 22118                    Jakarta                 Indonesia   -0.7893
# 29064              Cockburn Town  Turks and Caicos Islands   21.6940
# 32089                   Castries                 St. Lucia   13.9094
# 34999  Yaren District (de facto)                     Nauru   -0.5228
# 42916                Mexico City                    Mexico   23.6345
# 46461                    Palikir     Micronesia, Fed. Sts.    7.4256
#
#        longitude  Work Type  Company Size  ...                 Contact  \
# 3938   -168.7340   Contract         43302  ...    001-820-491-8513x925
# 6498    -56.0278   Contract        119965  ...    001-478-923-5589x259
# 14654   -88.4976     Intern         75341  ...      855.993.2801x23906
# 19652     1.5218   Contract         88449  ...      571.583.8907x77471
# 22118   113.9213     Intern         46940  ...   001-399-678-1239x7413
# 29064   -71.7979     Intern         84022  ...  001-925-967-7622x34903
# 32089   -60.9789   Contract         81385  ...              9992272098
# 34999   166.9315   Contract         90833  ...              2336242989
# 42916  -102.5528  Full-Time        128215  ...       (337)428-9147x366
# 46461   150.5508     Intern         76130  ...        643-805-7432x485
#
#            Job Title            Role           Job Portal  \
# 3938   Data Engineer  Data Architect             FlexJobs
# 6498   Data Engineer  Data Architect  Stack Overflow Jobs
# 14654  Data Engineer  Data Architect              USAJOBS
# 19652  Data Engineer  Data Architect  Stack Overflow Jobs
# 22118  Data Engineer  Data Architect         Jobs2Careers
# 29064  Data Engineer  Data Architect             Idealist
# 32089  Data Engineer  Data Architect            Glassdoor
# 34999  Data Engineer  Data Architect             FlexJobs
# 42916  Data Engineer  Data Architect              Monster
# 46461  Data Engineer  Data Architect             FlexJobs
#
#                                          Job Description  \
# 3938   A Data Architect designs and manages data infr...
# 6498   A Data Architect designs and manages data infr...
# 14654  A Data Architect designs and manages data infr...
# 19652  A Data Architect designs and manages data infr...
# 22118  A Data Architect designs and manages data infr...
# 29064  A Data Architect designs and manages data infr...
# 32089  A Data Architect designs and manages data infr...
# 34999  A Data Architect designs and manages data infr...
# 42916  A Data Architect designs and manages data infr...
# 46461  A Data Architect designs and manages data infr...
#
#                                                 Benefits  \
# 3938   {'Transportation Benefits, Professional Develo...
# 6498   {'Transportation Benefits, Professional Develo...
# 14654  {'Legal Assistance, Bonuses and Incentive Prog...
# 19652  {'Life and Disability Insurance, Stock Options...
# 22118  {'Legal Assistance, Bonuses and Incentive Prog...
# 29064  {'Employee Assistance Programs (EAP), Tuition ...
# 32089  {'Tuition Reimbursement, Stock Options or Equi...
# 34999  {'Tuition Reimbursement, Stock Options or Equi...
# 42916  {'Employee Referral Programs, Financial Counse...
# 46461  {'Transportation Benefits, Professional Develo...
#
#                                                   skills  \
# 3938   Data architecture design Database management s...
# 6498   Data architecture design Database management s...
# 14654  Data architecture design Database management s...
# 19652  Data architecture design Database management s...
# 22118  Data architecture design Database management s...
# 29064  Data architecture design Database management s...
# 32089  Data architecture design Database management s...
# 34999  Data architecture design Database management s...
# 42916  Data architecture design Database management s...
# 46461  Data architecture design Database management s...
#
#                                         Responsibilities  \
# 3938   Design data architecture and systems to meet b...
# 6498   Design data architecture and systems to meet b...
# 14654  Design data architecture and systems to meet b...
# 19652  Design data architecture and systems to meet b...
# 22118  Design data architecture and systems to meet b...
# 29064  Design data architecture and systems to meet b...
# 32089  Design data architecture and systems to meet b...
# 34999  Design data architecture and systems to meet b...
# 42916  Design data architecture and systems to meet b...
# 46461  Design data architecture and systems to meet b...
#
#                               Company  \
# 3938            Deutsche Lufthansa AG
# 6498                            Tesco
# 14654                       Microsoft
# 19652                        AutoZone
# 22118                   Siemens India
# 29064              Advance Auto Parts
# 32089  Commonwealth Bank of Australia
# 34999                        M&T Bank
# 42916              Plains GP Holdings
# 46461        Larsen & Toubro Infotech
#
#                                          Company Profile
# 3938   {"Sector":"Aviation and Travel","Industry":"Ai...
# 6498   {"Sector":"Retail","Industry":"Retail","City":...
# 14654  {"Sector":"Technology","Industry":"Computer So...
# 19652  {"Sector":"Automotive Parts","Industry":"Speci...
# 22118  {"Sector":"Industrial Conglomerates","Industry...
# 29064  {"Sector":"Automotive Parts","Industry":"Speci...
# 32089  {"Sector":"Banking","Industry":"Banking/Financ...
# 34999  {"Sector":"Financial Services","Industry":"Com...
# 42916  {"Sector":"Energy","Industry":"Pipelines","Cit...
# 46461  {"Sector":"Information Technology","Industry":...
#
# [10 rows x 23 columns]
